# %%
print('data')
# Out:
# data

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#         fecha grupo_muscular               ejercicio unidad_carga  carga  \
# 0  2026-03-09        Tríceps  Tríceps polea con lazo      panelas      8
# 1  2026-03-17        Tríceps  Tríceps polea con lazo      panelas      9
# 2  2026-03-17        Piernas       Flexor de rodilla      panelas      7
# 3  2026-03-19         Bíceps   Bícep supino en polea      panelas      6
# 4  2026-03-21          Pecho    Press plano asistido  kg_por_lado     30
#
#    series  repeticiones              notas
# 0       3            12   objetivo 15 reps
# 1       3            12   objetivo 15 reps
# 2       1            70  registro especial
# 3       3            12                NaN
# 4       2             5                NaN

# %%
data.groupby(["ejercicio"])["series"].sum()
# Out:
# ejercicio
# Abdominal crunch con polea              3
# Bícep polea supino                      3
# Bícep supino en polea                   3
# Extensor de rodilla                     6
# Femoral acostado                        3
# Flexor de rodilla                       7
# Halón polea                            12
# Halón polea agarre amplio               3
# Halón polea unilateral                  3
# Halón polea unilateral progresivo       3
# Hip thrust                              3
# Pantorrilla sentado                     3
# Patada de glúteo                        6
# Patada de glúteo polea unilateral       3
# Patada de glúteo unilateral             3
# Press inclinado                         4
# Press inclinado barra asistida          8
# Press plano                             2
# Press plano asistido                    2
# Remo cerrado                            3
# Tríceps polea con barra V               3
# Tríceps polea con barra V invertida     4
# ...

# %% [markdown]
# ## Normalization

# %%
data["ejercicio"].unique()
# Out:
# <StringArray>
# [             'Tríceps polea con lazo',                   'Flexor de rodilla',
#                'Bícep supino en polea',                'Press plano asistido',
#            'Tríceps polea con barra V',             'Tríceps polea tras nuca',
#             'Tríceps polea unilateral',                         'Halón polea',
#                   'Bícep polea supino',              'Tríceps polea con soga',
#                     'Patada de glúteo',                     'Press inclinado',
#                          'Press plano',                        'Remo cerrado',
#             'Vuelo lateral unilateral',      'Press inclinado barra asistida',
#  'Tríceps polea con barra V invertida',       'Tríceps polea unilateral drop',
#    'Patada de glúteo polea unilateral',                 'Extensor de rodilla',
#    'Halón polea unilateral progresivo',          'Abdominal crunch con polea',
#          'Patada de glúteo unilateral',           'Halón polea agarre amplio',
# ...

# %%
len(data["ejercicio"].unique())
# Out:
# 29

# %%
data_updated = data.copy()

# %%
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Flexor de rodilla", "Femoral acostado")

# %%
len(data_updated["ejercicio"].unique())
# Out:
# 28

# %%
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Bícep polea supino", "Bícep supino en polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Tríceps polea con barra V invertida", "Tríceps polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Tríceps polea con barra V", "Tríceps polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Tríceps polea con soga", "Tríceps polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Tríceps polea con lazo", "Tríceps polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Patada de glúteo unilateral", "Patada de glúteo")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Halón polea unilateral progresivo", "Halón polea unilateral")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Halón polea agarre amplio", "Halón polea")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Flexor de rodilla", "Femoral acostado")
data_updated["ejercicio"] = data_updated["ejercicio"].replace("Tríceps polea unilateral drop", "Tríceps polea unilateral")

# %%
len(data_updated["ejercicio"].unique())
# Out:
# 20

# %%
data_updated.groupby(["ejercicio"])["carga"].sum()
# Out:
# ejercicio
# Abdominal crunch con polea           10
# Bícep supino en polea                12
# Extensor de rodilla                  10
# Femoral acostado                     29
# Halón polea                          44
# Halón polea unilateral                9
# Hip thrust                           60
# Pantorrilla sentado                  20
# Patada de glúteo                     22
# Patada de glúteo polea unilateral     7
# Press inclinado                      50
# Press inclinado barra asistida       70
# Press plano                          30
# Press plano asistido                 30
# Remo cerrado                         11
# Tríceps polea                        62
# Tríceps polea tras nuca              17
# Tríceps polea unilateral             24
# Vuelo lateral unilateral              4
# Vuelos laterales sentado             18
# Name: carga, dtype: int64

# %% [markdown]
# ### Required queries
#
# 1. Time series of progress by excercise
# 2. Time series of progress by muscle group
# 3. Time series of weight oer excercise

# %%
data_updated.size
# Out:
# 392
